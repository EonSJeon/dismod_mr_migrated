# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pipeline as pipeline
import copy
print(pipeline.__file__)
# Out:
# /Users/jeonsang-eon/dismod_mr_migrated/reforged_mr/pipeline.py

# %%
import os

def list_all_csv_files(dir_path):
    """
    주어진 dir_path 아래의 모든 하위 디렉토리를 포함하여
    .csv 확장자를 가진 파일의 전체 경로를 리스트로 반환합니다.
    """
    csv_files = []
    for root, dirs, files in os.walk(dir_path):
        for file in files:
            if file.lower().endswith('.csv'):
                csv_files.append(os.path.join(root, file))
    return csv_files

dir_path = './data_ready/input_data'
csv_files = list_all_csv_files(dir_path)
csv_files
# Out:
# ['./data_ready/input_data/NR/joined_input_data_NR_Early.csv',
#  './data_ready/input_data/NR/joined_input_data_NR_Late-dry.csv',
#  './data_ready/input_data/NR/joined_input_data_NR_Intermediate.csv',
#  './data_ready/input_data/NR/joined_input_data_NR_Late-wet.csv',
#  './data_ready/input_data/Eth/African/joined_input_data_African_ancestry_Late-dry.csv',
#  './data_ready/input_data/Eth/African/joined_input_data_African_ancestry_Early to intermediate.csv',
#  './data_ready/input_data/Eth/African/joined_input_data_African_ancestry_Intermediate.csv',
#  './data_ready/input_data/Eth/African/joined_input_data_African_ancestry_Late-wet.csv',
#  './data_ready/input_data/Eth/European/joined_input_data_European_ancestry_Late-dry.csv',
#  './data_ready/input_data/Eth/European/joined_input_data_European_ancestry_Early.csv',
#  './data_ready/input_data/Eth/European/joined_input_data_European_ancestry_Intermediate.csv',
#  './data_ready/input_data/Eth/European/joined_input_data_European_ancestry_Late-wet.csv',
#  './data_ready/input_data/Eth/Hispanic/joined_input_data_Hispanic_Intermediate.csv',
#  './data_ready/input_data/Eth/Hispanic/joined_input_data_Hispanic_Early.csv',
#  './data_ready/input_data/Eth/Hispanic/joined_input_data_Hispanic_Late-wet.csv',
#  './data_ready/input_data/Eth/Hispanic/joined_input_data_Hispanic_Late-dry.csv',
#  './data_ready/input_data/Eth/Asian/joined_input_data_Asian_ancestry_Early.csv',
#  './data_ready/input_data/Eth/Asian/joined_input_data_Asian_ancestry_Late-wet.csv',
#  './data_ready/input_data/Eth/Asian/joined_input_data_Asian_ancestry_Late-dry.csv',
#  './data_ready/input_data/Eth/Asian/joined_input_data_Asian_ancestry_Intermediate.csv']

# %%
basedir = '/Users/jeonsang-eon/dismod_mr_migrated/reforged_mr/data_ready/params'

input_data_path =csv_files[0]
output_template_path = f'{basedir}/output_template.csv'
detailed_pop_path=f'{basedir}/pop_detailed.csv'
parameters_path = f'{basedir}/parameters.jsonc'
hierarchy_path = f'{basedir}/hierarchy.json' 
input_data_path
# Out:
# './data_ready/input_data/NR/joined_input_data_NR_Early.csv'

# %%
pm_model = pipeline.initialize_pipeline(
    input_data_path=input_data_path,
    output_template_path=output_template_path,
    parameters_path=parameters_path,
    hierarchy_path=hierarchy_path,
    detailed_pop_path=detailed_pop_path,
    verbose=False
)
pipeline.generate_pymc_objects(pm_model, data_type='p')

map_estimate = pipeline.return_map_estimate(pm_model=pm_model, verbose=True)
idata = pipeline.return_idata(pm_model     = pm_model, 
                            map_estimate   = map_estimate, 
                            draws          = 4000,
                            tune           = 1000,
                            chains         = 4,
                            cores          = 4,
                            target_accept  = 0.9,
                            use_advi       = False,
                            verbose=False,
                            use_metropolis=False,
                            nuts_max_treedepth=10,
                            ) 
pred = pipeline.predict_for(pm_model            = pm_model,
                            idata               = idata, 
                            root_area           = 'Global',
                            root_sex            = 'Both',
                            root_year           = 'all',
                            location_id                = 1,
                            sex_name                 = 'Both',
                            year_id                = 2021,
                            population_weighted = True,
                            lower               = 0.0,
                            upper               = 1.0,
                            include_covariates  = False,
                            return_scalar       = False,
                            )
# 198.3초 소요
pipeline.visualize_pred(pred, pm_model.shared_data["input_data_p"])
# Out:
# Standard errors replaced: 0
# Effective sample sizes filled: 0
# rate_type: neg_binom
# INFO:pipeline:[VAR] gammas=['gamma_p']
# INFO:pipeline:[VAR] betas =['beta_p_x_lpa', 'beta_p_x_sev', 'beta_p_x_sex']
# INFO:pipeline:[VAR] alphas=['alpha_p_56', 'alpha_p_62', 'alpha_p_64', 'alpha_p_71', 'alpha_p_65', 'alpha_p_68', 'alpha_p_69', 'alpha_p_100', 'alpha_p_102', 'alpha_p_73', 'alpha_p_80', 'alpha_p_81', 'alpha_p_83', 'alpha_p_84', 'alpha_p_86', 'alpha_p_89', 'alpha_p_90', 'alpha_p_92', 'alpha_p_95', 'alpha_p_103', 'alpha_p_107', 'alpha_p_134', 'alpha_p_135', 'alpha_p_137', 'alpha_p_138', 'alpha_p_142', 'alpha_p_158', 'alpha_p_159', 'alpha_p_163', 'alpha_p_4', 'alpha_p_5', 'alpha_p_8', 'alpha_p_166', 'alpha_p_174', 'alpha_p_180']
# INFO:pipeline:[VAR] s.alp =['sigma_alpha_p_0_z', 'sigma_alpha_p_1_z', 'sigma_alpha_p_2_z', 'sigma_alpha_p_3_z']
# INFO:pipeline:[VAR] disp  =['eta_p']
# INFO:pipeline:▶ Stage-wise MAP initialization started
# INFO:pipeline:— Outer loop 1/3
# INFO:pipeline:[MAP] spline (monolithic) (Powell): gamma_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='2429' class='' max='2429' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2429/2429 00:01&lt;00:00 logp = -1,455.1]
#     </div>
# INFO:pipeline:[MAP] random effects (bulk) (Powell): alpha_p_56, alpha_p_62, alpha_p_64, alpha_p_71, alpha_p_65, alpha_p_68, alpha_p_69, alpha_p_100, alpha_p_102, alpha_p_73, alpha_p_80, alpha_p_81, alpha_p_83, alpha_p_84, alpha_p_86, alpha_p_89, alpha_p_90, alpha_p_92, alpha_p_95, alpha_p_103, alpha_p_107, alpha_p_134, alpha_p_135, alpha_p_137, alpha_p_138, alpha_p_142, alpha_p_158, alpha_p_159, alpha_p_163, alpha_p_4, alpha_p_5, alpha_p_8, alpha_p_166, alpha_p_174, alpha_p_180
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3712' class='' max='3712' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3712/3712 00:03&lt;00:00 logp = -1,341.8]
#     </div>
# INFO:pipeline:[MAP] RE hyper (sigma_alpha_*) (L-BFGS-B): sigma_alpha_p_0_z, sigma_alpha_p_1_z, sigma_alpha_p_2_z, sigma_alpha_p_3_z
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12' class='' max='12' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12/12 00:00&lt;00:00 logp = -1,332.5, ||grad|| = 0.00055128]
#     </div>
# INFO:pipeline:[MAP] spline (monolithic) (Powell): gamma_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='965' class='' max='965' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [965/965 00:00&lt;00:00 logp = -1,331.3]
#     </div>
# INFO:pipeline:[MAP] fixed effects (first 1/3) (Powell): beta_p_x_lpa
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='46' class='' max='46' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [46/46 00:00&lt;00:00 logp = -1,324.7]
#     </div>
# INFO:pipeline:[MAP] fixed effects (first 2/3) (Powell): beta_p_x_lpa, beta_p_x_sev
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='102' class='' max='102' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [102/102 00:00&lt;00:00 logp = -1,322.5]
#     </div>
# INFO:pipeline:[MAP] fixed effects (first 3/3) (Powell): beta_p_x_lpa, beta_p_x_sev, beta_p_x_sex
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='93' class='' max='93' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [93/93 00:00&lt;00:00 logp = -1,322.5]
#     </div>
# INFO:pipeline:[MAP] spline (monolithic) (Powell): gamma_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='683' class='' max='683' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [683/683 00:00&lt;00:00 logp = -1,321.9]
#     </div>
# INFO:pipeline:[MAP] dispersion (eta_/zeta_*) (L-BFGS-B): eta_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00&lt;00:00 logp = -1,321.9, ||grad|| = 11.728]
#     </div>
# INFO:pipeline:— Outer loop 2/3
# INFO:pipeline:[MAP] spline (monolithic) (Powell): gamma_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='324' class='' max='324' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [324/324 00:00&lt;00:00 logp = -1,320.2]
#     </div>
# INFO:pipeline:[MAP] random effects (bulk) (Powell): alpha_p_56, alpha_p_62, alpha_p_64, alpha_p_71, alpha_p_65, alpha_p_68, alpha_p_69, alpha_p_100, alpha_p_102, alpha_p_73, alpha_p_80, alpha_p_81, alpha_p_83, alpha_p_84, alpha_p_86, alpha_p_89, alpha_p_90, alpha_p_92, alpha_p_95, alpha_p_103, alpha_p_107, alpha_p_134, alpha_p_135, alpha_p_137, alpha_p_138, alpha_p_142, alpha_p_158, alpha_p_159, alpha_p_163, alpha_p_4, alpha_p_5, alpha_p_8, alpha_p_166, alpha_p_174, alpha_p_180
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1324' class='' max='1324' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1324/1324 00:01&lt;00:00 logp = -1,315.1]
#     </div>
# INFO:pipeline:[MAP] RE hyper (sigma_alpha_*) (L-BFGS-B): sigma_alpha_p_0_z, sigma_alpha_p_1_z, sigma_alpha_p_2_z, sigma_alpha_p_3_z
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6' class='' max='6' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [6/6 00:00&lt;00:00 logp = -1,315.1, ||grad|| = 2.0741]
#     </div>
# INFO:pipeline:[MAP] spline (monolithic) (Powell): gamma_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='692' class='' max='692' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [692/692 00:00&lt;00:00 logp = -1,314]
#     </div>
# INFO:pipeline:[MAP] fixed effects (first 1/3) (Powell): beta_p_x_lpa
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='46' class='' max='46' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [46/46 00:00&lt;00:00 logp = -1,312.5]
#     </div>
# INFO:pipeline:[MAP] fixed effects (first 2/3) (Powell): beta_p_x_lpa, beta_p_x_sev
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='109' class='' max='109' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [109/109 00:00&lt;00:00 logp = -1,311.1]
#     </div>
# INFO:pipeline:[MAP] fixed effects (first 3/3) (Powell): beta_p_x_lpa, beta_p_x_sev, beta_p_x_sex
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='99' class='' max='99' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [99/99 00:00&lt;00:00 logp = -1,311.1]
#     </div>
# INFO:pipeline:[MAP] spline (monolithic) (Powell): gamma_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='679' class='' max='679' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [679/679 00:00&lt;00:00 logp = -1,310.8]
#     </div>
# INFO:pipeline:[MAP] dispersion (eta_/zeta_*) (L-BFGS-B): eta_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00&lt;00:00 logp = -1,310.8, ||grad|| = 2.9157]
#     </div>
# INFO:pipeline:— Outer loop 3/3
# INFO:pipeline:[MAP] spline (monolithic) (Powell): gamma_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='354' class='' max='354' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [354/354 00:00&lt;00:00 logp = -1,310.6]
#     </div>
# INFO:pipeline:[MAP] random effects (bulk) (Powell): alpha_p_56, alpha_p_62, alpha_p_64, alpha_p_71, alpha_p_65, alpha_p_68, alpha_p_69, alpha_p_100, alpha_p_102, alpha_p_73, alpha_p_80, alpha_p_81, alpha_p_83, alpha_p_84, alpha_p_86, alpha_p_89, alpha_p_90, alpha_p_92, alpha_p_95, alpha_p_103, alpha_p_107, alpha_p_134, alpha_p_135, alpha_p_137, alpha_p_138, alpha_p_142, alpha_p_158, alpha_p_159, alpha_p_163, alpha_p_4, alpha_p_5, alpha_p_8, alpha_p_166, alpha_p_174, alpha_p_180
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='1314' class='' max='1314' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1314/1314 00:01&lt;00:00 logp = -1,308.6]
#     </div>
# INFO:pipeline:[MAP] RE hyper (sigma_alpha_*) (L-BFGS-B): sigma_alpha_p_0_z, sigma_alpha_p_1_z, sigma_alpha_p_2_z, sigma_alpha_p_3_z
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='7' class='' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [7/7 00:00&lt;00:00 logp = -1,308.6, ||grad|| = 0.43412]
#     </div>
# INFO:pipeline:[MAP] spline (monolithic) (Powell): gamma_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='692' class='' max='692' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [692/692 00:00&lt;00:00 logp = -1,308.1]
#     </div>
# INFO:pipeline:[MAP] fixed effects (first 1/3) (Powell): beta_p_x_lpa
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='38' class='' max='38' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [38/38 00:00&lt;00:00 logp = -1,307.5]
#     </div>
# INFO:pipeline:[MAP] fixed effects (first 2/3) (Powell): beta_p_x_lpa, beta_p_x_sev
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='72' class='' max='72' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [72/72 00:00&lt;00:00 logp = -1,306.6]
#     </div>
# INFO:pipeline:[MAP] fixed effects (first 3/3) (Powell): beta_p_x_lpa, beta_p_x_sev, beta_p_x_sex
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='73' class='' max='73' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [73/73 00:00&lt;00:00 logp = -1,306.6]
#     </div>
# INFO:pipeline:[MAP] spline (monolithic) (Powell): gamma_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='713' class='' max='713' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [713/713 00:00&lt;00:00 logp = -1,306.3]
#     </div>
# INFO:pipeline:[MAP] dispersion (eta_/zeta_*) (L-BFGS-B): eta_p
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='5' class='' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:00&lt;00:00 logp = -1,306.3, ||grad|| = 1.8267]
#     </div>
# INFO:pipeline:▶ Final full MAP
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3' class='' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3/3 00:00&lt;00:00 logp = -1,306.3, ||grad|| = 107.98]
#     </div>
# INFO:pipeline:✓ MAP initialization finished.
# INFO:pipeline:  ▶ NUTS 샘플링 수행 중...
# Auto-assigning NUTS sampler...
# INFO:pymc:Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# INFO:pymc:Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# INFO:pymc:Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [gamma_p, sigma_alpha_p_0_z, sigma_alpha_p_1_z, sigma_alpha_p_2_z, sigma_alpha_p_3_z, alpha_p_56, alpha_p_62, alpha_p_64, alpha_p_71, alpha_p_65, alpha_p_68, alpha_p_69, alpha_p_100, alpha_p_102, alpha_p_73, alpha_p_80, alpha_p_81, alpha_p_83, alpha_p_84, alpha_p_86, alpha_p_89, alpha_p_90, alpha_p_92, alpha_p_95, alpha_p_103, alpha_p_107, alpha_p_134, alpha_p_135, alpha_p_137, alpha_p_138, alpha_p_142, alpha_p_158, alpha_p_159, alpha_p_163, alpha_p_4, alpha_p_5, alpha_p_8, alpha_p_166, alpha_p_174, alpha_p_180, beta_p_x_lpa, beta_p_x_sev, beta_p_x_sex, eta_p]
# INFO:pymc:NUTS: [gamma_p, sigma_alpha_p_0_z, sigma_alpha_p_1_z, sigma_alpha_p_2_z, sigma_alpha_p_3_z, alpha_p_56, alpha_p_62, alpha_p_64, alpha_p_71, alpha_p_65, alpha_p_68, alpha_p_69, alpha_p_100, alpha_p_102, alpha_p_73, alpha_p_80, alpha_p_81, alpha_p_83, alpha_p_84, alpha_p_86, alpha_p_89, alpha_p_90, alpha_p_92, alpha_p_95, alpha_p_103, alpha_p_107, alpha_p_134, alpha_p_135, alpha_p_137, alpha_p_138, alpha_p_142, alpha_p_158, alpha_p_159, alpha_p_163, alpha_p_4, alpha_p_5, alpha_p_8, alpha_p_166, alpha_p_174, alpha_p_180, beta_p_x_lpa, beta_p_x_sev, beta_p_x_sex, eta_p]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 19:52&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 4_000 draw iterations (4_000 + 16_000 draws total) took 1193 seconds.
# INFO:pymc:Sampling 4 chains for 1_000 tune and 4_000 draw iterations (4_000 + 16_000 draws total) took 1193 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# INFO:pymc:The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# ERROR:pymc:The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# INFO:pipeline:[asr] 전체 소요 시간: 1236.0초
# /Users/jeonsang-eon/dismod_mr_migrated/reforged_mr/pipeline.py:1136: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   hpd = pm.stats.hdi(pred, hdi_prob=0.95)

# %%
summary_df = pipeline.return_rhat(idata)
# Out:
# Total vars:    1519
# R-hat > 1.01:  1457
# R-hat <= 1.01:  0
# R-hat missing: 62
# <xarray.Dataset> Size: 23kB
# Dimensions:               (knot_p: 21, age: 101, cum_sum_mu_p_dim_0: 101,
#                            mu_interval_p_dim_0: 274, re_loc_id_p: 41,
#                            fe_eff_name_p: 4, pi_p_dim_0: 274, obs_dim_p: 274,
#                            p_pred_p_dim_0: 274)
# Coordinates:
#   * knot_p                (knot_p) float64 168B 0.0 5.0 10.0 ... 90.0 95.0 100.0
#   * age                   (age) int32 404B 0 1 2 3 4 5 6 ... 95 96 97 98 99 100
#   * cum_sum_mu_p_dim_0    (cum_sum_mu_p_dim_0) int64 808B 0 1 2 3 ... 98 99 100
#   * mu_interval_p_dim_0   (mu_interval_p_dim_0) int64 2kB 0 1 2 ... 271 272 273
#   * re_loc_id_p           (re_loc_id_p) int64 328B 31 56 62 64 ... 8 166 174 180
#   * fe_eff_name_p         (fe_eff_name_p) <U5 80B 'x_lpa' 'x_sdi' ... 'x_sex'
#   * pi_p_dim_0            (pi_p_dim_0) int64 2kB 0 1 2 3 4 ... 270 271 272 273
#   * obs_dim_p             (obs_dim_p) int64 2kB 0 1 2 3 4 ... 270 271 272 273
#   * p_pred_p_dim_0        (p_pred_p_dim_0) int64 2kB 0 1 2 3 ... 270 271 272 273
# Data variables: (12/64)
#     gamma_p               (knot_p) float64 168B 4.199 4.059 3.028 ... 3.55 3.53
#     sigma_alpha_p_0_z     float64 8B 4.258
#     sigma_alpha_p_1_z     float64 8B 3.099
#     sigma_alpha_p_2_z     float64 8B 3.868
#     sigma_alpha_p_3_z     float64 8B 3.425
#     alpha_p_56            float64 8B 3.049
#     ...                    ...
#     alpha_p               (re_loc_id_p) float64 328B 3.748 3.049 ... 3.284 3.871
#     beta_p_x_sdi          float64 8B nan
#     beta_p                (fe_eff_name_p) float64 32B 3.231 nan 3.691 3.631
#     pi_p                  (pi_p_dim_0) float64 2kB 4.549 4.313 ... 4.549 3.54
#     delta_p               (obs_dim_p) float64 2kB 4.254 4.254 ... 4.254 4.254
#     p_pred_p              (p_pred_p_dim_0) float64 2kB 4.549 4.313 ... 3.54

# %%
import numpy as np
import arviz as az

# 1) posterior 변수 이름 중에 'beta' 포함된 것만 추출
beta_vars = [var for var in idata.posterior.data_vars if 'beta_p_' in var]
print("Found beta variables:", beta_vars)

# 2) NumPy로 직접 mean 계산 (chain, draw 차원 평균)
mean_beta = {
    var: idata.posterior[var].values.mean(axis=(0, 1))
    for var in beta_vars
}

# 결과 출력
for var, m in mean_beta.items():
    print(f"{var} mean:\n{m}\n")


# —— 또는 —— #

# 3) ArviZ의 summary로 한 번에 보기
summary_beta = az.summary(idata, var_names=beta_vars)
print(summary_beta[['mean']])

# 2) 90% HDI로 변경하고 싶을 때
summary_beta_90 = az.summary(
    idata,
    var_names=beta_vars,
    stat_focus="mean",
    hdi_prob=0.90,          # 90% HDI
    round_to=4
)
print(summary_beta_90[['mean', 'hdi_5%', 'hdi_95%']])
# Out:
# Found beta variables: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t3/6wjz0w9511d3t31xphnn6jbr0000gn/T/ipykernel_10806/382990245.py in ?()
# ---> 22 import numpy as np
#      23 import arviz as az
#      24
#      25 # 1) posterior 변수 이름 중에 'beta' 포함된 것만 추출
#
# ~/miniconda3/envs/dismod_mr_mig/lib/python3.9/site-packages/arviz/stats/stats.py in ?(data, var_names, filter_vars, group, fmt, kind, round_to, circ_var_names, stat_focus, stat_funcs, extend, hdi_prob, skipna, labeller, coords, index_origin, order)
#    1393     metrics: List[xr.Dataset] = []
#    1394     metric_names: List[str] = []
#    1395     if extend and kind in ["all", "stats"]:
#    1396         if stat_focus == "mean":
# -> 1397             mean = dataset.mean(dim=("chain", "draw"), skipna=skipna)
#    1398
#    1399             sd = dataset.std(dim=("chain", "draw"), ddof=1, skipna=skipna)
#    1400
#
# ~/miniconda3/envs/dismod_mr_mig/lib/python3.9/site-packages/xarray/core/_aggregations.py in ?(self, dim, skipna, keep_attrs, **kwargs)
#     505         Dimensions:  ()
#     506         Data variables:
#     507             da       float64 8B nan
#     508         """
# --> 509         return self.reduce(
#     510             duck_array_ops.mean,
#     511             dim=dim,
#     512             skipna=skipna,
#
# ~/miniconda3/envs/dismod_mr_mig/lib/python3.9/site-packages/xarray/core/dataset.py in ?(self, func, dim, keep_attrs, keepdims, numeric_only, **kwargs)
#    6961             dims = set(dim)
#    6962
#    6963         missing_dimensions = tuple(d for d in dims if d not in self.dims)
#    6964         if missing_dimensions:
# -> 6965             raise ValueError(
#    6966                 f"Dimensions {missing_dimensions} not found in data dimensions {tuple(self.dims)}"
#    6967             )
#    6968
#
# ValueError: Dimensions ('draw', 'chain') not found in data dimensions ()

# %%
import pandas as pd
import numpy as np

# === 1) pred 불러오기 ===
# 예: pred = pipeline.predict_for(...)
# pred.shape == (n_samples, n_ages)  # 여기서는 (32000, 101)

# === 2) 통계량 계산 ===
mean_vals    = pred.mean(axis=0)
lower_vals   = np.percentile(pred,  2.5, axis=0)
upper_vals   = np.percentile(pred, 97.5, axis=0)

# === 3) DataFrame 생성 ===
ages = np.arange(pred.shape[1])  # 0,1,2,...,100

df = pd.DataFrame({
    'mean'     : mean_vals,
    'lower_ci' : lower_vals,
    'upper_ci' : upper_vals
}, index=ages)

df.index.name = 'age'

# === 4) CSV로 저장 ===
out_path = f'prevalence_2021_2.csv'
df.to_csv(out_path)
print(f"Saved summary to {out_path}")
# Out:
# Saved summary to prevalence_2021_2.csv

# %%
results = pipeline.world_predict(
    pm_model,
    idata,
    years=list(range(1990, 2022)),
    output_csv_path=f'1990_2021_all_regions.csv'
)
# Out:
# /Users/jeonsang-eon/dismod_mr_migrated/reforged_mr/model/spline.py
# /Users/jeonsang-eon/dismod_mr_migrated/reforged_mr/model/priors.py
# /Users/jeonsang-eon/dismod_mr_migrated/reforged_mr/model/age_groups.py
# /Users/jeonsang-eon/dismod_mr_migrated/reforged_mr/model/covariates.py
# /Users/jeonsang-eon/dismod_mr_migrated/reforged_mr/model/likelihood.py
# [world_predict] Saved 7232 rows to '1990_2021_all_regions.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def plot_global_triple_trend(
    df: pd.DataFrame,
    save_path: str = "global_triple_trend.png",
    percent=True,
    cases_unit=1e6
):
    gdf = df[df["level"] == 0].copy()

    counts = gdf["year"].value_counts()
    duplicates = counts[counts > 1]
    if not duplicates.empty:
        raise ValueError(f"Global rows have duplicate years: {duplicates.index.tolist()}")

    required_cols = [
        "year",
        "mean_prev","lower_prev","upper_prev",
        "mean_prev_std","lower_prev_std","upper_prev_std",
        "mean_cases","lower_cases","upper_cases"
    ]
    missing = [c for c in required_cols if c not in gdf.columns]
    if missing:
        raise KeyError(f"Missing columns in df: {missing}")

    agg = gdf.sort_values("year")[required_cols].reset_index(drop=True)

    scale = 100.0 if percent else 1.0
    years = agg["year"].to_numpy()

    y_prev      = agg["mean_prev"].to_numpy() * scale
    y_prev_lo   = agg["lower_prev"].to_numpy() * scale
    y_prev_hi   = agg["upper_prev"].to_numpy() * scale

    y_prev_std    = agg["mean_prev_std"].to_numpy() * scale
    y_prev_std_lo = agg["lower_prev_std"].to_numpy() * scale
    y_prev_std_hi = agg["upper_prev_std"].to_numpy() * scale

    y_cases      = agg["mean_cases"].to_numpy() / cases_unit
    y_cases_lo   = agg["lower_cases"].to_numpy() / cases_unit
    y_cases_hi   = agg["upper_cases"].to_numpy() / cases_unit

    # 색상 팔레트에서 3가지 색 선택
    colors = plt.get_cmap("tab10").colors
    c1, c2, c3 = colors[0], colors[1], colors[2]

    fig, ax = plt.subplots(figsize=(8.5, 5))

    # 유병률
    line1, = ax.plot(years, y_prev, linewidth=2, color=c1, label="Prevalence")
    ax.fill_between(years, y_prev_lo, y_prev_hi, alpha=0.2, linewidth=0, color=c1)

    # 표준화 유병률
    line2, = ax.plot(years, y_prev_std, linewidth=2, linestyle="--", color=c2, label="Standardized prevalence")
    ax.fill_between(years, y_prev_std_lo, y_prev_std_hi, alpha=0.15, linewidth=0, color=c2)

    ax.set_xlabel("Year")
    ax.set_ylabel(f"Prevalence ({'%' if percent else 'per 1'})")
    ax.grid(True, alpha=0.3)

    # 절대 환자수
    ax2 = ax.twinx()
    line3, = ax2.plot(years, y_cases, linewidth=2, color=c3, label=f"Cases (/{int(cases_unit):,})")
    ax2.fill_between(years, y_cases_lo, y_cases_hi, alpha=0.15, linewidth=0, color=c3)
    ax2.set_ylabel(f"Cases (× {int(cases_unit):,})")

    # 범례
    lines = [line1, line2, line3]
    labels = [ln.get_label() for ln in lines]
    ax.legend(lines, labels, loc="upper left")

    plt.title("Global AMD: Prevalence, Standardized Prevalence, and Cases Over Time")
    plt.tight_layout()
    plt.savefig(save_path, dpi=200)
    plt.show()



# 사용 예시
# df = world_predict(...)
plot_global_triple_trend(results, "global_prev_trend.png")

# %%
# Out:
# /Users/jeonsang-eon/dismod_mr_migrated/reforged_mr/pipeline.py:919: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   raise ValueError(f"age_weights length ({len(vec)}) != len(ages) ({len(ages)}).")

# %%
# 3) (간단) pickle로 저장
import pickle
pkl_path = f"./idata_2021.pkl"
with open(pkl_path, "wb") as f:
    pickle.dump(idata, f)
print(f"Pickled InferenceData to {pkl_path}")
# Out:
# Pickled InferenceData to ./idata_2021.pkl

# %%
years_of_interest = list(range(1990, 2022))
ages_of_interest = list(range(30, 101))
pop_glo_yrs_age_path = 'data_ready/params/pop_glo_yrs_ages.csv'
output_csv_path = 'data_ready/params/time_trend.csv'
pipeline.time_trend(
    pm_model=pm_model,
    idata=idata,
    years_of_interest=years_of_interest,
    ages_of_interest=ages_of_interest,
    pop_glo_yrs_age_path=pop_glo_yrs_age_path,
    output_csv_path=output_csv_path,
    is_std_pop=True,
    is_plot=True
)
# Out:
# [time_trend] Saved CSV to 'data_ready/params/time_trend.csv'
#     year_id  mean_prev  lower_95  upper_95
# 0      1990   0.112071  0.095662  0.132667
# 1      1991   0.111861  0.095536  0.132093
# 2      1992   0.111608  0.095402  0.131627
# 3      1993   0.111303  0.095314  0.130922
# 4      1994   0.110949  0.095155  0.130351
# 5      1995   0.110581  0.094963  0.129680
# 6      1996   0.110175  0.094704  0.128872
# 7      1997   0.109723  0.094397  0.127949
# 8      1998   0.109251  0.094183  0.127110
# 9      1999   0.108785  0.093945  0.126261
# 10     2000   0.108356  0.093633  0.125424
# 11     2001   0.107949  0.093378  0.124776
# 12     2002   0.107533  0.093094  0.124120
# 13     2003   0.107131  0.092738  0.123606
# 14     2004   0.106747  0.092463  0.123130
# 15     2005   0.106400  0.092284  0.122757
# 16     2006   0.106072  0.092051  0.122398
# 17     2007   0.105786  0.091841  0.122081
# 18     2008   0.105499  0.091586  0.121728
# 19     2009   0.105248  0.091308  0.121466
# 20     2010   0.105010  0.091093  0.121156
# 21     2011   0.104737  0.090820  0.120860
# 22     2012   0.104447  0.090566  0.120452
# 23     2013   0.104155  0.090165  0.120169
# 24     2014   0.103889  0.089810  0.119996
# 25     2015   0.103666  0.089561  0.119754
# 26     2016   0.103485  0.089272  0.119700
# 27     2017   0.103340  0.089096  0.119678
# 28     2018   0.103230  0.088928  0.119734
# 29     2019   0.103136  0.088715  0.119732
# 30     2020   0.103094  0.088607  0.119803
# 31     2021   0.103095  0.088623  0.119891
