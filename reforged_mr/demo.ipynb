# %%
import pipeline as pipeline
print(pipeline.__file__)
# Out:
# /Users/Dev/AMD/dismod_mr_migrated/reforged_mr/pipeline.py

# %%
input_dir  = './input_data'
stage_dirs = ['amd_sim_data', 'amd_sim_data_Early', 'amd_sim_data_Intermediate', 'amd_sim_data_Late-dry', 'amd_sim_data_Late-wet']
stage      = stage_dirs[2] # Intermediate

pm_model = pipeline.initiliaze_pipeline(f'{input_dir}/{stage}', data_type='p', verbose=True)
# Out:
# number of rows: 207
# number of unique location_id: 18
# number of nodes: 233
# number of edges: 232

# %%
pipeline.describe_hierarchy(pm_model)
# Out:
# Global (1)
#   Central Europe, Eastern Europe, and Central Asia (31)
#     Central Asia (32)
#       Armenia (33)
#       Azerbaijan (34)
#       Georgia (35)
#       Kazakhstan (36)
#       Kyrgyzstan (37)
#       Mongolia (38)
#       Tajikistan (39)
#       Turkmenistan (40)
#       Uzbekistan (41)
#     Central Europe (42)
#       Albania (43)
#       Bosnia and Herzegovina (44)
#       Bulgaria (45)
#       Croatia (46)
#       Czechia (47)
#       Hungary (48)
#       Montenegro (50)
#       North Macedonia (49)
#       Poland (51)
#       Romania (52)
#       Serbia (53)
#       Slovakia (54)
#       Slovenia (55)
#     Eastern Europe (56)
#       Belarus (57)
#       Estonia (58)
#       Latvia (59)
#       Lithuania (60)
#       Republic of Moldova (61)
#       Russian Federation (62)
#       Ukraine (63)
#   High-income (64)
#     Australasia (70)
#       Australia (71)
#       New Zealand (72)
#     High-income Asia Pacific (65)
#       Brunei Darussalam (66)
# ...

# %%
pipeline.describe_data(pm_model)
